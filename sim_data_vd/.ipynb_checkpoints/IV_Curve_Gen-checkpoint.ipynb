# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
# VGS sweep 
steps = np.arange(100)
print(steps)
plt.figure(figsize=(10,6))


for item in steps:
    #file = f"{item}_mosfetVGS_MC_all.csv"
    file = f"/home/oliviag/ngspice-skywater-sims/sim_data/run_{item}.csv"
    if not os.path.exists(file):
        continue
    data1 = np.loadtxt(file, delimiter=",", skiprows=1)
    
    
   
    vg1 = data1[:,1]
    idrain1 = -data1[:,3]  
    vth1 = data1[1,4] #changing param
    #vd1 = data1[0,5]
    #plt.figure(figsize=(10,6))
    plt.plot(vg1, idrain1 * 1e6, label=f"{item}")
    print(f"done: {item}")
    
plt.xlim(0, 1.85)                              
plt.xticks(np.arange(0, 1.9, 0.2))

plt.title("Sky130 NMOS Id–Vgs")
plt.xlabel("VGS (V)")
plt.ylabel("Id (uA)")
plt.legend()
plt.grid(True)
    
plt.tight_layout()
plt.show()

#VDS sweep 
dSteps = ['0', '1', '2', '3', '4']
plt.figure(figsize=(10,6))


for step in dSteps:
    DS = np.loadtxt(f"{step}_mosfetVDS_MC_all.csv", delimiter=",", skiprows=1)

    
    
    vd3 = DS[:,0]
    id3 = -DS[:,3] 
    vth2 = DS[1,4]
    #vg3 = DS[0,1]
    
    
    plt.plot(vd3, id3 * 1e6)   
plt.xlim(0, 1.85)                              
plt.xticks(np.arange(0, 1.9, 0.2))
plt.title("Sky130 NMOS Id–Vds")
plt.xlabel("VDS (V)")
plt.ylabel("Id (uA)")
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
#   Cell In[49], line 21
#     plt.plot(vg1, idrain1 * 1e6, label=f"{item}"))
#                                                  ^
# SyntaxError: unmatched ')'
